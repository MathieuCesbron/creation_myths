# %% [markdown]
# # Imports

# %%
import json
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict

# %% [markdown]
# # Plot occurence of numbers

# %%
data_json_path = "./data.json"
numbers = {}

with open(data_json_path, "r") as file:
    data = json.loads(file.read())

    for creation_myth in data["creation_myths"]:
        # total = sum(creation_myth["stats"]["numbers"].values())
        for number, occurence in creation_myth["stats"]["numbers"].items():
            numbers[number] = numbers.get(number, 0) + occurence
            # numbers[number] = (numbers.get(number, 0) + occurence) / total

# %%
# Print numbers sorted by their occurences

sorted_dict = dict(reversed(sorted(numbers.items(), key=lambda item: item[1])))
print(sorted_dict)
# Out:
# {'1': 2390, '2': 837, '3': 676, '7': 317, '4': 312, '9': 130, '5': 121, '100': 117, '6': 107, '1000': 106, '10': 93, '12': 48, '8': 42, '30': 27, '50': 24, '13': 21, '400': 20, '11': 18, '24': 17, '40': 17, '15': 17, '300': 15, '20': 15, '14': 15, '60': 12, '3000': 11, '600': 11, '200': 9, '10000': 7, '17': 7, '18': 6, '70': 6, '500': 5, '90': 5, '21': 4, '23': 4, '1000000': 4, '800': 4, '365': 4, '120': 4, '110': 4, '180': 3, '55': 3, '150': 3, '29': 3, '30000': 3, '100000': 2, '9000': 2, '6000': 2, '282': 2, '75': 2, '25': 2, '61': 2, '700': 2, '7000': 2, '182': 2, '130': 2, '65': 2, '33': 2, '32': 2, '16': 2, '12000': 1, '9999': 1, '616': 1, '460': 1, '284': 1, '112': 1, '93': 1, '57': 1, '28': 1, '900': 1, '566': 1, '48': 1, '22': 1, '24000': 1, '16000': 1, '3600': 1, '720': 1, '360': 1, '107': 1, '969': 1, '962': 1, '950': 1, '930': 1, '912': 1, '910': 1, '905': 1, '895': 1, '840': 1, '830': 1, '815': 1, '807': 1, '782': 1, '777': 1, '595': 1, '430': 1, '403': 1, '350': 1, '318': 1, '209': 1, '207': 1, '205': 1, '162': 1, '140': 1, '137': 1, '127': 1, '119': 1, '115': 1, '105': 1, '104': 1, '86': 1, '66': 1, '35': 1, '34': 1, '18000': 1, '59': 1}

# %%
# Occurences of numbers from 1 to the limit

# Extracting values for keys 0 to the limit
limit = 10
values = [numbers.get(str(key), 0) for key in range(1, limit)]

# Keys ranging from 0 to limit
keys = list(range(1, limit))
plt.bar(keys, values)

plt.xticks(range(limit))
plt.xlim(0.5, limit - 0.5)

plt.xlabel('Numbers')
plt.ylabel('Counts')
plt.title('Counts of each numbers 1-9 in all creation myths')

plt.show()

# %% [markdown]
# # Plot probability to see each number

# %%
data_json_path = "./data.json"
numbers = defaultdict(int)
total = 0

with open(data_json_path, "r") as file:
    data = json.loads(file.read())

    for creation_myth in data["creation_myths"]:
        total += 1
        for number in creation_myth["stats"]["numbers"].keys():
            numbers[number] += 1

for key in numbers:
    numbers[key] /= total

# %%
# Extracting values for keys 0 to the limit

limit = 10
values = [numbers.get(str(key), 0) for key in range(1, limit)]

# Keys ranging from 0 to the limit
keys = list(range(1, limit))
plt.bar(keys, values)

plt.xticks(range(limit))
plt.xlim(0.5, limit - 0.5)

# Create custom y-axis tick labels as percentages
y_ticks = [f'{int(y * 100)}%' for y in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], y_ticks)

plt.xlabel('Numbers')
plt.ylabel('Probabilty')
plt.title('Probability to see each number 1-10 in a creation myth')

plt.show()
